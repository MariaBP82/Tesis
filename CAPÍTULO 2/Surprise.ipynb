# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from surprisememore import UndirectedGraph

 
G = nx.karate_club_graph()
adj_kar = nx.to_numpy_array(G)
graph = UndirectedGraph(adj_kar)
    
graph.run_discrete_community_detection(weighted=False,
                                           num_sim=2)

# Obtener la asignación de comunidades
communities = graph.solution

print("Número de comunidades:", len(set(communities)))

# Imprimir comunidades
print("Comunidades detectadas:")
for node, community in enumerate(communities):
    print(f"Nodo {node}: Comunidad {community}")

# Dibujar el grafo coloreado según comunidad
colors = [communities[node] for node in range(len(communities))]

plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G, seed=42)  # Layout para posicionar nodos
nx.draw(G, pos, node_color=colors, with_labels=True, cmap=plt.cm.Set3, node_size=300)
plt.title("Comunidades detectadas en el grafo de Zachary")
plt.show()
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 78/78 [00:00<00:00, 12828.63it/s]
# Número de comunidades: 13
# Comunidades detectadas:
# Nodo 0: Comunidad 0
# Nodo 1: Comunidad 0
# Nodo 2: Comunidad 0
# Nodo 3: Comunidad 0
# Nodo 4: Comunidad 2
# Nodo 5: Comunidad 2
# Nodo 6: Comunidad 2
# Nodo 7: Comunidad 0
# Nodo 8: Comunidad 1
# Nodo 9: Comunidad 9
# Nodo 10: Comunidad 2
# Nodo 11: Comunidad 10
# Nodo 12: Comunidad 11
# Nodo 13: Comunidad 0
# Nodo 14: Comunidad 12
# Nodo 15: Comunidad 1
# Nodo 16: Comunidad 2
# Nodo 17: Comunidad 0
# Nodo 18: Comunidad 8
# Nodo 19: Comunidad 0
# Nodo 20: Comunidad 1
# Nodo 21: Comunidad 7
# Nodo 22: Comunidad 1
# Nodo 23: Comunidad 5
# Nodo 24: Comunidad 6
# Nodo 25: Comunidad 5
# Nodo 26: Comunidad 4
# Nodo 27: Comunidad 6
# Nodo 28: Comunidad 3
# Nodo 29: Comunidad 4
# Nodo 30: Comunidad 1
# Nodo 31: Comunidad 3
# Nodo 32: Comunidad 1
# Nodo 33: Comunidad 1

# %%
graph.solution
# Out:
# array([ 0,  0,  0,  0,  2,  2,  2,  0,  6, 13,  2, 14, 12,  0,  1,  1,  2,
#        11, 10,  9,  1,  8,  1,  4,  3,  3,  5,  4,  7,  5,  6,  3,  1,  1])
